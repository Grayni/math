# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi, np.pi, 201)
plt.plot(x, np.sin(x), color='pink')
plt.plot(x, np.cos(x), color='#777fff')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(color='#eeefff')
